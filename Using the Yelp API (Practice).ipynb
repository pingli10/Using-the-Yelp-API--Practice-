# %%
import pandas as pd
from yelpapi import YelpAPI
import json

# %%
#
with open('/Users/pinl/.secret/yelp_api.json') as f:
    login=json.load(f)
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
yelp_api = YelpAPI(login['API Key'],timeout_s=5.0)
yelp_api

# %%
coffee_q = yelp_api.search_query(location='Greenville, SC',
                               term='coffee')
type(coffee_q)
coffee_q.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
coffee = pd.DataFrame(coffee_q['businesses'])
coffee.head(2)
# Out:
#                        id                             alias  \
# 0  f0cnaDfsLDT3k8TViSw8xg      methodical-coffee-greenville
# 1  Ul2BwqWIpbNEEfqSPX8y9A  chestnut-coffee-house-greenville
#
#                     name                                          image_url  \
# 0      Methodical Coffee  https://s3-media1.fl.yelpcdn.com/bphoto/pJ-PES...
# 1  Chestnut Coffee House  https://s3-media3.fl.yelpcdn.com/bphoto/hM5QlI...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/methodical-coffee-gre...           252
# 1      False  https://www.yelp.com/biz/chestnut-coffee-house...            15
#
#                                           categories  rating  \
# 0     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]     4.5
# 1  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     5.0
#
#                                          coordinates transactions price  \
# ...

# %%
coffee_q['total']
# Out:
# 366

# %%
len(coffee_0['businesses'])
# Out:
# 20

# %%
# add offset to our original api call
coffee_20 = yelp_api.search_query(location='Greenville, SC',
                               term='coffee',
                                offset = 20)

# %%
coffee20 = pd.DataFrame(coffee_20['businesses'])
coffee20.head(2)
# Out:
#                        id                                       alias  \
# 0  iNkIrw_yc5kijHto0VqCNQ                         barista-alley-greer
# 1  MMW3v2N88icfGFjpFh2KKA  swamp-rabbit-cafe-and-grocery-greenville-2
#
#                             name  \
# 0                  Barista Alley
# 1  Swamp Rabbit Cafe and Grocery
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/vbRsPm...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/4qv65Z...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/barista-alley-greer?a...           111
# 1  https://www.yelp.com/biz/swamp-rabbit-cafe-and...           232
#
#                                           categories  rating  \
# 0  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 1  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
#
# ...

# %%
# concat all pages
final_coffee = pd.concat([coffee,coffee20],
                      ignore_index=True)
display(final_coffee.head(3),final_coffee.tail(3))
# Out:
#                        id                             alias  \
# 0  f0cnaDfsLDT3k8TViSw8xg      methodical-coffee-greenville
# 1  Ul2BwqWIpbNEEfqSPX8y9A  chestnut-coffee-house-greenville
# 2  Fo0K-3Xvzy7LgK4k15XWBQ      the-village-grind-greenville
#
#                     name                                          image_url  \
# 0      Methodical Coffee  https://s3-media1.fl.yelpcdn.com/bphoto/pJ-PES...
# 1  Chestnut Coffee House  https://s3-media3.fl.yelpcdn.com/bphoto/hM5QlI...
# 2      The Village Grind  https://s3-media1.fl.yelpcdn.com/bphoto/MEGy-g...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/methodical-coffee-gre...           252
# 1      False  https://www.yelp.com/biz/chestnut-coffee-house...            15
# 2      False  https://www.yelp.com/biz/the-village-grind-gre...           127
#
#                                           categories  rating  \
# ...

# %%
final_coffee.to_json(orient='records')
# Out:
# '[{"id":"f0cnaDfsLDT3k8TViSw8xg","alias":"methodical-coffee-greenville","name":"Methodical Coffee","image_url":"https:\\/\\/s3-media1.fl.yelpcdn.com\\/bphoto\\/pJ-PESbcl4wF7qSEzi46Ug\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/methodical-coffee-greenville?adjust_creative=Yzd_r2eGdKI-OKPwiCyWGg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Yzd_r2eGdKI-OKPwiCyWGg","review_count":252,"categories":[{"alias":"coffee","title":"Coffee & Tea"}],"rating":4.5,"coordinates":{"latitude":34.8519379,"longitude":-82.3996038521},"transactions":["delivery"],"price":"$$","location":{"address1":"101 N Main St","address2":"Ste D","address3":"","city":"Greenville","zip_code":"29601","country":"US","state":"SC","display_address":["101 N Main St","Ste D","Greenville, SC 29601"]},"phone":"+18647358407","display_phone":"(864) 735-8407","distance":3860.2807210741},{"id":"Ul2BwqWIpbNEEfqSPX8y9A","alias":"chestnut-coffee-house-greenville","name":"Chestnut Coffee Ho
# ...
